# %%
# IMPORT LIBRARIES

import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
# READ DATA

Data = pd.read_csv('movies.csv')

# %%
Data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
Data.shape
# Out:
# (7668, 15)

# %%
Data.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
Data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ### DATA CLEANING

# %%
# QUERY COLUMN DATA

Data.query('budget=="NAN"')
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
# MISSING VALUES

Data.isna().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# DROP ALL MISSING DATA

Data = Data.dropna()

# %%
# REVIEW MISSING VALUES

Data.isna().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# COLUMNS CONVERT TO INTEGER

Data['budget'] = Data['budget'].astype('int64')
Data['gross'] = Data['gross'].astype('int64')

Data.dtypes
# Out:
# C:\Users\Kelnnin\AppData\Local\Temp\ipykernel_10568\1145288955.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['budget'] = Data['budget'].astype('int64')
# C:\Users\Kelnnin\AppData\Local\Temp\ipykernel_10568\1145288955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['gross'] = Data['gross'].astype('int64')
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# ...

# %%
# VIEW DATA AGAIN

Data
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# ### DATA EXPLORATION

# %%
# HIGHEST GROSSING MOVIE

Data.sort_values(by = ['gross'], ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# CHECK DUPLICATE

Data.loc[Data.duplicated(subset = ['name', 'year', 'budget'])]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
# QUERY COLUMN DATA

Data.query('name == "Impulse"')
# Out:
#          name rating   genre  year                            released  score  \
# 603   Impulse      R  Horror  1984  September 28, 1984 (United States)    5.9
# 1836  Impulse      R   Crime  1990       April 6, 1990 (United States)    5.7
#
#        votes      director          writer             star        country  \
# 603   1300.0  Graham Baker  Nicholas Kazan     Tim Matheson  United States
# 1836  1200.0  Sondra Locke    John DeMarco  Theresa Russell  United States
#
#         budget    gross              company  runtime
# 603   10000000  2773433  ABC Motion Pictures     91.0
# 1836   9000000  2544504         Warner Bros.    109.0

# %%
# SUPOSSITIONS
#1 BUDGET (HIGH CORRELATION WITH GROSS EARNINGS)
#2 DIRECTOR 
#3 GENRE

# %% [markdown]
# ### DATA VISUALIZATION

# %%
# SCATTER PLOT

ax = Data.plot(kind = 'scatter', x = 'gross', y = 'budget', figsize = (12,8))
ax.set_xlabel('Gross earnings')
# Out:
# Text(0.5, 0, 'Gross earnings')

# %%
# REG PLOT

plt.figure(figsize=(12, 8))
sns.regplot(data = Data, x = 'budget', y = 'gross', scatter_kws = {'color':'red'}, line_kws = {'color':'black'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# CORRELATION

Data.dropna()
Data.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# ASIGN A NEW VARIABLE 

Data_corr = Data.corr()

# %%
# SUPPOSITIONS
#1 BUDGET TO A CERTAIN HAS A HIGH DEGREE OF INFLUENCE OR CORRELATES MOST WITH PROFIT GROWTH

Data_corr.sort_values(by = ['budget'], ascending = False)
# Out:
#              year     score     votes    budget     gross   runtime
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068

# %%
# RENAME COLUMN

Data_corr = Data_corr.rename(columns = {'gross': 'earnings'})
Data_corr
# Out:
#              year     score     votes    budget  earnings   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# HEAT MAP - (CORRELATION DEFAULT)

sns.heatmap(Data_corr, annot = True)
plt.title('Movie Data Corr')
plt.xlabel('Attribute')
# Out:
# Text(0.5, 23.52222222222222, 'Attribute')

# %%
# HEAT MAP - (CORRELATION KENDALL)

Data_corr = Data.corr(method = 'kendall')
sns.heatmap(Data_corr, annot = True)
plt.title('Movie Data Corr')
plt.xlabel('Attribute')
# Out:
# Text(0.5, 23.52222222222222, 'Attribute')

# %%
# CONVERT OBJECT DATA IN NUMBER DATA TO REANALYZE

Data_numerized = Data.copy()

for col_names in Data_numerized.columns:
    if(Data_numerized[col_names].dtype == 'object'):
        Data_numerized[col_names] = Data_numerized[col_names].astype('category')
        Data_numerized[col_names] = Data_numerized[col_names].cat.codes
        
Data_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3      204       4      4  1980      1127    7.7   221000.0       889    1413
# 4      732       6      4  1980      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       713    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       904    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       370    6.8     3700.0       746    1184
#
# ...

# %%
Data
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# CORRELATION BETWEEN NUMBERS

Data_numerized_corr = Data_numerized.corr()

Data_numerized_corr
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
# SORT BY GROSS

Data_numerized_corr.sort_values(by = ['gross'], ascending = False)
# Out:
#               name    rating     genre      year  released     score  \
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# runtime   0.010850  0.140792 -0.059237  0.075077  0.008975  0.414068
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# company   0.021697 -0.092357 -0.071334 -0.014333 -0.002407  0.020656
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# ...

# %%
# HEAT MAP (DATA NUMERIZED)- (CORRELATION DEFAULT)

plt.figure(figsize = (12,8))
sns.heatmap(data = Data_numerized_corr)
plt.title('Movie Data Corr')
plt.xlabel('Attribute')
# Out:
# Text(0.5, 58.7222222222222, 'Attribute')

# %%
# HEAT MAP (DATA NUMERIZED)- (CORRELATION DEFAULT)

plt.figure(figsize = (12,8))
sns.heatmap(Data_numerized_corr, annot = True)
plt.title('Movie Data Corr')
plt.xlabel('Attribute')
# Out:
# Text(0.5, 58.7222222222222, 'Attribute')

# %%
# CORRELATION DATA EVEN FURTHER

Data_numerized_corr_unstack = Data_numerized_corr.unstack()

Data_numerized_corr_unstack_pair = Data_numerized_corr_unstack.sort_values()

Data_numerized_corr_unstack_pair
# Out:
# budget   genre     -0.368523
# genre    budget    -0.368523
#          gross     -0.244101
# gross    genre     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %% [markdown]
# ### CONCLUSIONS

# %%
# BUDGET AND VOTES HIGHEST CORRELATION WITH GROSS / EARNINGS
# COMPANY SMALLEST CORRELATION WITH GROSS / EARNINGS
